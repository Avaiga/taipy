# %%
from taipy.gui import Gui, Markdown

# %%
a = 10
page = Markdown("# Hello\n<|{a}|>")

# %%
gui = Gui()
gui.add_page("page1", page)

# %%
gui.run(run_browser=False)

# %%
gui.state.a

# %%
gui.state.a = 20

# %%
gui.state.a

# %%
gui.stop()

# %%
gui.run(run_browser=False)

# %%
gui.reload()

# %%
gui.stop()
